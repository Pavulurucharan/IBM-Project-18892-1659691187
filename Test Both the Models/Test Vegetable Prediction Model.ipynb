# %%
train_dir=r'C:\Users\Sree Ram\Desktop\ibm\Dataset Plant Disease\Veg-dataset\Veg-dataset\train_set'
test_dir=r'C:\Users\Sree Ram\Desktop\ibm\Dataset Plant Disease\Veg-dataset\Veg-dataset\test_set'

# %%
import tensorflow as tf 
from tensorflow import keras 
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# # Load The Model

# %%
model = tf.keras.models.load_model(r'C:\Users\Sree Ram\Desktop\ibm\Dataset Plant Disease\vegetable.h5')

# %%
test_datagen_1=ImageDataGenerator(rescale=1)
test_generator_1=test_datagen_1.flow_from_directory(
    test_dir,
    target_size=(128,128),
    batch_size=20,
    class_mode='categorical'
)
# Out:
# Found 3416 images belonging to 9 classes.

# %% [markdown]
# # Evaluate

# %%
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image

# %%
img=image.load_img(r'C:\Users\Sree Ram\Desktop\ibm\Dataset Plant Disease\Veg-dataset\Veg-dataset\train_set\Pepper,_bell___Bacterial_spot\0d8421cd-eebc-4018-b591-12352dd970a7___JR_B.Spot 3234.JPG')

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256>

# %%
img=image.load_img(r"C:\Users\Sree Ram\Desktop\ibm\Dataset Plant Disease\Veg-dataset\Veg-dataset\train_set\Pepper,_bell___Bacterial_spot\0d8421cd-eebc-4018-b591-12352dd970a7___JR_B.Spot 3234.JPG",target_size=(128,128))
x=image.img_to_array(img)
x=np.expand_dims(x,axis=0)
y=np.argmax(model.predict(x),axis=1)
index=['Pepper,_bell___Bacterial_spot', 'Pepper,_bell___healthy', 'Potato___Early_blight', 'Potato___healthy', 'Potato___Late_blight', 'Tomato___Bacterial_spot','Tomato___Late_blight','Tomato___Leaf_Mold','Tomato___Septoria_leaf_spot']
index[y[0]]
# Out:
# 1/1 [==============================] - 0s 157ms/step
# 'Pepper,_bell___Bacterial_spot'

# %%
model.evaluate(test_generator_1,steps=50)
# Out:
# 50/50 [==============================] - 3s 64ms/step - loss: 0.1831 - accuracy: 0.9360
# [0.18312719464302063, 0.9359999895095825]
