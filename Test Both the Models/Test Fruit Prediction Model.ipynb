# %%
train_dir=r'C:\Users\Sree Ram\Desktop\ibm\Dataset Plant Disease\fruit-dataset\fruit-dataset\train'
test_dir=r'C:\Users\Sree Ram\Desktop\ibm\Dataset Plant Disease\fruit-dataset\fruit-dataset\test'

# %%
import tensorflow as tf 
from tensorflow import keras 
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# # Load The Model

# %%
model = tf.keras.models.load_model(r'C:\Users\Sree Ram\Desktop\ibm\Dataset Plant Disease\fruit.h5')

# %%
test_datagen_1=ImageDataGenerator(rescale=1)
test_generator_1=test_datagen_1.flow_from_directory(
    test_dir,
    target_size=(128,128),
    batch_size=20,
    class_mode='categorical'
)
# Out:
# Found 1686 images belonging to 6 classes.

# %% [markdown]
# # Evaluate

# %%
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image

# %%
img=image.load_img(r"C:\Users\Sree Ram\Desktop\ibm\Dataset Plant Disease\fruit-dataset\fruit-dataset\train\Corn_(maize)___healthy\9fd94da5-5b0b-436a-8097-2288ec52a0f1___R.S_HL 8110 copy.jpg")

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256>

# %%
img=image.load_img(r"C:\Users\Sree Ram\Desktop\ibm\Dataset Plant Disease\fruit-dataset\fruit-dataset\train\Corn_(maize)___healthy\9fd94da5-5b0b-436a-8097-2288ec52a0f1___R.S_HL 8110 copy.jpg",target_size=(128,128))
x=image.img_to_array(img)
x=np.expand_dims(x,axis=0)
y=np.argmax(model.predict(x),axis=1)
index=['Apple___Black_rot', 'Apple___healthy', 'Corn_(maize)___healthy', 'Corn_(maize)___Northern_Leaf_Blight', 'Peach___Bacterial_spot', 'Peach___healthy']
index[y[0]]
# Out:
# 1/1 [==============================] - 2s 2s/step
# 'Corn_(maize)___Northern_Leaf_Blight'

# %%
model.evaluate(test_generator_1,steps=50)
# Out:
# 50/50 [==============================] - 3s 63ms/step - loss: 0.3054 - accuracy: 0.9370
# [0.3054291605949402, 0.9369999766349792]
